# %% [markdown]
# # drugMR: Notebook Interface
#
# This notebook provides an interactive interface for running the **drugMR** pipeline.
#
# ## Requirements
#
# - Access to the Falcon HPC cluster.
# - SSH authentication configured for Falcon (see README.md).
# - A local Python environment capable of running this notebook.
# - The `drugMR` GitHub repository cloned locally.
#
# > **Note:** Computationally intensive analyses are executed on Falcon within an Apptainer (pulled from Docker) container. The local environment is used only for result retrival and dashboard creation.

# %%
import sys
import subprocess
import importlib
from pathlib import Path

print("[TRACKING] Installing local dependencies...")

subprocess.run([sys.executable, "-m", "pip", "install", "--quiet", "--disable-pip-version-check", "-r", "../env/requirements.txt",], check=True, stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL,)
subprocess.run([sys.executable, "-m", "pip", "install", "scipy", "pyyaml"], check=True)

print("[DONE] Local dependencies ready.")

project_root = Path("..").resolve()

if str(project_root) not in sys.path:
    sys.path.append(str(project_root))

import drugmr as dm # drugMR package

print("[DONE] drugMR loaded!")

# %% [markdown]
# # Running drugMR in HPC
#
# > **Note:** This command runs the GWAS QC and cis-MR workflows on the SLURM HPC. It then retrieves the results, stores them in a local PostgreSQL database, and generates the dashboard.

# %%
dm.hpc(config="assets/config.yaml")

# %% [markdown]
# # Running drugMR Locally
#
# > **Note:** This command runs the GWAS QC and cis-MR workflows locally using Docker. It then retrieves the results, stores them in a local PostgreSQL database, and generates the dashboard.

# %%
dm.local(config="assets/config.yaml")

# %% [markdown]
# #### This occurs in a local env (regardless of whether you ran drugMR in HPC or locally)

# %%
dm.results(
    pqtl_dataset=pqtl_dataset,
    pheno_id=pheno_id,
)
