# %%
import sys
from pathlib import Path
sys.path.append(str(Path("../").resolve()))

# %%
import sys
print(sys.version)
! python --version
# Out:
# 3.9.6 (default, Apr  7 2026, 02:38:40)
# [Clang 21.0.0 (clang-2100.0.123.102)]
# Python 3.9.6

# %%
falcon_user  = ""
pheno_id     = "AD"
sumstats     = "AD_raw.tsv"
n_cases      = 35274
n_controls   = 59163
genome_build = "GRCh37"
pqtl_dataset = "ukb_ppp"
pqtl_dir     = "dat/ukb_ppp"
ref_bfile    = "ref/1000G.EUR.QC.ALL"
postgres_db  = "drugmr"

# %%
clone_repo(falcon_user)
container_checks(falcon_user)
