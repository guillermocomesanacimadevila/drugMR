# %% [markdown]
# # drugMR: Notebook Interface
#
# This notebook provides an interactive interface for running the **drugMR** pipeline.
#
# ## Requirements
#
# - Access to the Falcon HPC cluster.
# - SSH authentication configured for Falcon (see README.md).
# - A local Python environment capable of running this notebook.
# - The `drugMR` GitHub repository cloned locally.
#
# > **Note:** Computationally intensive analyses are executed on Falcon within an Apptainer container to ensure reproducibility. The local environment is used only for orchestration, result retrieval, and dashboard creation.

# %%
import sys
import subprocess
import importlib
from pathlib import Path

print("[TRACKING] Installing local dependencies...")

packages = ["pandas", "polars", "sqlalchemy", "psycopg2-binary", "streamlit", "plotly"]
subprocess.run([sys.executable, "-m", "pip", "install", "--quiet", "--disable-pip-version-check", *packages], check=True, stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)

print("[DONE] Local dependencies ready.")

project_root = Path("..").resolve()

if str(project_root) not in sys.path:
    sys.path.append(str(project_root))

wf = importlib.import_module("workflows.hpc")

print("[DONE] drugMR workflows imported.")

# %%
falcon_user  = ""
pheno_id     = "AD"
sumstats     = "dat/gwas/AD_ldsc_ready_neff.tsv"
n_cases      = 21982
n_controls   = 41944
genome_build = "GRCh37"
pqtl_dataset = "ukb_ppp"
pqtl_dir     = "dat/pqtls/ukb_ppp"
ref_bfile    = "ref/ldsc/1000G_EUR_Phase3_plink/1000G.EUR.QC.ALL"
postgres_db  = "drugmr"

# %%
wf.clone_repo(falcon_user)
wf.container_checks(falcon_user)

# %%
wf.run_gwas_qc(
    falcon_user=falcon_user,
    pheno_id=pheno_id,
    sumstats=sumstats,
    out_dir="results",
    snp_col="SNP",
    a1_col="A1",
    a2_col="A2",
    beta_col="BETA",
    se_col="SE",
    p_col="P",
    pos_col="POS",
    chr_col="CHR",
    af_col="FRQ",
    genome_build=genome_build,
    n_cases=n_cases,
    n_controls=n_controls,
)

# %%
wf.run_cis_mr(
    falcon_user=falcon_user,
    pqtl_dataset=pqtl_dataset,
    pqtl_dir=pqtl_dir,
    pheno_id=pheno_id,
    pheno_gwas=f"results/QC/{pheno_id}/{pheno_id}.tsv",
    ref_bfile=ref_bfile,
)

# %%
wf.pull_results_local(
    falcon_user=falcon_user,
    pqtl_dataset=pqtl_dataset,
    pheno_id=pheno_id,
    local_results_dir="../results/cis-MR",
    overwrite=True
)

# %%
# !python ../bin/load_db_into_postgres.py \
    --mr_res ../results/cis-MR/{pqtl_dataset}_{pheno_id}_all_MR.tsv \
    --db_id {postgres_db} \
    --pqtl_dataset {pqtl_dataset} \
    --pheno_id {pheno_id}

# %%
# !python -m streamlit run ../dashboard/mr_app.py -- \
    --db_name {postgres_db} \
    --port_number 5432 \
    --phenotype {pheno_id}
